# %%
import pandas as pd
import requests
# import eventlet
from bs4 import BeautifulSoup
from geopy.geocoders import Nominatim

# %%
from geopy.exc import GeocoderUnavailable

# %%
url = 'https://www.apartments.com/indianapolis-in/1/'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'}
response = requests.get(url, headers=headers, timeout=30)

# %%
soup = BeautifulSoup(response.text)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-placeholder-focus="false" id="appContainer" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="email=no" name="format-detection"/>
#   <meta content="true" name="HandheldFriendly"/>
#   <title>
#    Apartments For Rent in Indianapolis, IN - 9,678 Rentals | Apartments.com
#   </title>
#   <link href="/a/8a55f9/favicon.ico" rel="icon"/>
#   <link href="https://www.apartments.com/indianapolis-in/" rel="canonical"/>
#   <meta content="max-image-preview:large" name="robots"/>
#   <meta content="Get a great Indianapolis, IN rental on Apartments.com! Use our search filters to browse all 9,678 apartments and score your perfect place! " name="description"/>
#   <meta content="en" name="language"/>
#   <meta content="en" http-equiv="language"/>
#   <meta content="en-US" http-equiv="content-language"/>
# ...

# %%
name = []
for i in soup.find_all('span',class_='js-placardTitle title'):
    name.append(i.text.strip())

# %%
print(len(name))
# Out:
# 25

# %%
print(name)
# Out:
# ['Everly at Meridian Hills', 'Solana at the Crossing', 'The Block', 'Lake Clearwater Apartments', 'Briergate', 'Brookwood Apartments', 'The Residences on 56th Street', 'Kingston Square Apartments', 'Madison Lofts', 'The Vue', 'Industry Indianapolis', 'The Coil', 'The Domain at Bennett Farms', 'Circa Apartments', 'River West Flats', 'Ivy Knoll Apartments', 'The MK', 'The Lodge at Trails Edge', 'Edison at Meridian Hills', 'Gathyr Apartments', 'Iron Works at Keystone', 'The Preserve on Allisonville Townhomes', 'Lakes of Windsor', 'Pinnex', 'TGM Shadeland Station']

# %%
url = 'https://www.apartments.com/indianapolis-in/2/'
response = requests.get(url, headers=headers, timeout=30)
soup = BeautifulSoup(response.text)
for i in soup.find_all('span',class_='js-placardTitle title'):
    name.append(i.text.strip())

# %%
print(len(name))
# Out:
# 50

# %%
for i in range(3,28):
    url = 'https://www.apartments.com/indianapolis-in/{}/'.format(i)
    response = requests.get(url, headers=headers, timeout=30)
    soup = BeautifulSoup(response.text)
    for j in soup.find_all('span',class_='js-placardTitle title'):
        name.append(j.text.strip())

# %%
print(len(name))
# Out:
# 867

# %%
final_name = [] 

for i in name: 
    if i not in final_name: 
        final_name.append(i)

# %%
print(len(final_name))
# Out:
# 604

# %%
address = []
for i in range(1,28):
    url = 'https://www.apartments.com/indianapolis-in/{}/'.format(i)
    response = requests.get(url, headers=headers, timeout=30)
    soup = BeautifulSoup(response.text)
    for j in soup.find_all('div',class_='property-address js-url'):
        address.append(j.text.strip())

# %%
print(len(address))
# Out:
# 625

# %%
len(address)
print(address)


for i in range(1,54):
    address.append(None)
# Out:
# ['9117 Briergate Ct, Indianapolis, IN 46229', '5301 S Turtle Creek South Dr, Indianapolis, IN 46227', '6800 Brendon Way W Dr, Indianapolis, IN 46226', '7171 Twin Oaks Dr, Indianapolis, IN 46226', '1430 Madison Ave, Indianapolis, IN 46225', '718 E Georgia St, Indianapolis, IN 46202', '421 N Pennsylvania St, Indianapolis, IN 46204', '6349 N College Ave, Indianapolis, IN 46220', '832 Park Central Ct, Indianapolis, IN 46260', '7745 Solana Dr, Indianapolis, IN 46240', '50 N Illinois St, Indianapolis, IN 46204', '3914 Lake Clearwater Pl, Indianapolis, IN 46240', '5000 Bennett Pky, Zionsville, IN 46077', '617 N College, Indianapolis, IN 46204', '5707 A Ivy Knoll Dr, Indianapolis, IN 46250', '1150 N White River Pkwy West Dr, Indianapolis, IN 46222', '5858 N College Ave, Indianapolis, IN 46220', '9535 Benchmark Dr, Indianapolis, IN 46240', '811 Antique Ct, Indianapolis, IN 46260', '1117 E Market St, Indianapolis, IN 46202', '5830 River Wood Dr, Indianapolis, IN 46250', '2727 E 86th St, Indian
# ...

# %%
address.append(None)

# %%
print(len(address))
# Out:
# 679

# %%
pricing = []

for i in range(1,28):
    url = 'https://www.apartments.com/indianapolis-in/{}/'.format(i)
    response = requests.get(url, headers=headers, timeout=30)
    soup = BeautifulSoup(response.text)
    for j in soup.find_all('p',class_='property-pricing') or soup.find_all('div',class_='price-range'):
        pricing.append(j.text.strip())

# %%
len(pricing)
# Out:
# 623

# %%
for i in range(1,4):
    pricing.append(-1)

# %%
print(len(pricing))
pricing.append(-1)
# Out:
# 626

# %%
df=pd.DataFrame({'name':final_name,
    'Location':address,
    'Price range':pricing,
    })

# %%
df.tail(100)
# Out:
#                       name                                       Location  \
# 527  1 S Harding St Unit B      7171 Twin Oaks Dr, Indianapolis, IN 46226
# 528     5322 Claybrooke Dr       1430 Madison Ave, Indianapolis, IN 46225
# 529       1724 McDowell Ct       718 E Georgia St, Indianapolis, IN 46202
# 530      4824 Ossington Ct  421 N Pennsylvania St, Indianapolis, IN 46204
# 531      10473 Windward Dr     6349 N College Ave, Indianapolis, IN 46220
# ..                     ...                                            ...
# 622        2031 Sharon Ave                         Indianapolis, IN 46214
# 623          12645 Roan Ln                         Indianapolis, IN 46222
# 624       6903 Hardwood Dr                         Indianapolis, IN 46236
# 625       1143 Stockton St                                           None
# 626         343 Polaris Dr                                           None
#
#     Price range
# 527  $1,770 /mo
# 528  $1,965 /mo
# 529  $1,920 /mo
# ...

# %%
df.to_excel(r'Indy2.xlsx', index=False)

# %%
locator = Nominatim(user_agent="Indy")
location = locator.geocode("1430 Madison Ave, Indianapolis, IN 46225")

# %%
print("Latitude = {}, Longitude = {}".format(location.latitude, location.longitude))
# Out:
# Latitude = 39.74751045, Longitude = -86.15480072029024

# %%
longi = []
lati = []
location = locator.geocode("9117 Briergate Ct, Indianapolis, IN 46229")
longi.append(location.longitude)
lati.append(location.latitude)

# %%
long1 = []
lat1 = []
try:
    for i in address:
        location = locator.geocode(i)  # Geocode the current address
        lat1.append(location.latitude)
        long1.append(location.longitude)
except NameError:
    long1.append(None)
    lat1.append(None)  
except AttributeError:
    long1.append(None)
    lat1.append(None)   
except GeocoderUnavailable:
    long1.append(None)
    lat1.append(None)

# %%
location = locator.geocode("6800 Brendon Way W Dr, Indianapolis, IN 46226")
longi.append(location.longitude)
lati.append(location.latitude)

# %%
len(long1)
print(long1)
# Out:
# [None]
